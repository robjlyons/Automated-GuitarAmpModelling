# %% [markdown]
# # Example of Different Model Training
# The following script illustrates the multiple methods of prepairing the data and training models.

# %%
# !python prep_wav.py -h

# %% [markdown]
# # Normalized Snapshot Training without Distinct Test Set
# This is the simplest method available. All that is required is a recording of the clean input data and the processed/dirty output data at one condition (setting of knobs on the analog hardware).
#
# The ```-s``` option denotes a "snapshot" model. The first argument is the clean input wav file, the second argument is the processed output wave file. Optionally, the third and fourth arguments may be a clean test input wav file and a processed test output wav file. An example is shown below.
#
# The training will seed all random number generators with 39 and will run for 100 epochs.
#
# ### CAUTION: The test data set is the same as the validaiton set. This will give a biased result on the performance of the model.

# %%
# !python prep_wav.py "LPB1_ex1"\
-s "./Recordings/20211003_LPB-1_5_min_Pink_Ramp_Clean.wav" \
"./Recordings/20211003_LPB-1_5_min_Pink_Ramp_Dirty.wav" \
 --normalize true

# %%
# !python dist_model_recnet.py -l RNN3-LPB1-ex1 -eps 5 --seed 39

# %% [markdown]
# # Snapshot with Random Training/Validation Split and Separate Test Set
# The following settings perform a random 20% split on between the training and validation data. The split works by slicing the input audio into 100 even slices and chosing a certain number of them. Also here is defined a separate test data set which prevents the biasing of the results from the validation information leaking.
#
# ### CAUTION: The random split between training and validation data may give unexpected results because the size of the devisions is long enough to maintain time dependency which also means that the Central Limit Theorm is not valid.

# %%
# !python prep_wav.py "LPB1_ex2"\
-s "./Recordings/20211003_LPB-1_5_min_Pink_Ramp_Clean.wav" \
"./Recordings/20211003_LPB-1_5_min_Pink_Ramp_Dirty.wav" \
"./Recordings/20211003_LPB-1_Natalie_Guitar_Clean.wav" \
"./Recordings/20211003_LPB-1_Natalie_Guitar_Dirty.wav" \
-rs 20

# %%
# !python dist_model_recnet.py -l RNN3-LPB1-ex2 -eps 5

# %% [markdown]
# # Parameterized Model
# The following settings prepair the data to create a parameterized model. A parameterization configuration file must be created. An example configuration file is included. The example is for one parameter, but any number of parameters up to 65355-(number of audio chanels) parameters may be defined. The limit is due to the number of channels allowed in a WAV file.
#
# The training instructions must then be modified to included the extra inputs to the model as ```-is <parameters + audio channels>``` That is, the number of inputs to the model must be the number of parameters plus the number of audio chanels. So for our example, ```-is 2```.
#
# As is the default, the trainging and validation data is split on modulus of 5 which gives a 20 percent split.

# %%
# !python prep_wav.py "LPB1_Parameterized" -p "./Configs/Parameterization-Config.json"
# Out:
# Parameterized Data
# /home/micahtseng/Personal/mlamsk/python3Env/pytorchSandbox/Automated-GuitarAmpModelling/prep_wav.py:169: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   in_rate, in_data = wavfile.read(ds["TrainingClean"])
# /home/micahtseng/Personal/mlamsk/python3Env/pytorchSandbox/Automated-GuitarAmpModelling/prep_wav.py:170: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   out_rate, out_data = wavfile.read(ds["TrainingTarget"])
# /home/micahtseng/Personal/mlamsk/python3Env/pytorchSandbox/Automated-GuitarAmpModelling/prep_wav.py:171: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   test_in_rate, test_in_data = wavfile.read(ds["TestClean"])
# /home/micahtseng/Personal/mlamsk/python3Env/pytorchSandbox/Automated-GuitarAmpModelling/prep_wav.py:172: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   test_out_rate, test_out_data = wavfile.read(ds["TestTarget"])

# %%
# !python dist_model_recnet.py -l RNN3-LPB1_Parameterized -eps 175 --seed 39 -lm False -is 2
# Out:
# no saved model found, creating new network
# cuda device available
# unimplemented audio data type conversion...
# unimplemented audio data type conversion...
# unimplemented audio data type conversion...
# unimplemented audio data type conversion...
# unimplemented audio data type conversion...
# unimplemented audio data type conversion...
# Epoch:  1
# current learning rate: 0.005
# Epoch:  2
# Val loss: tensor(0.7114)
# current learning rate: 0.005
# Epoch:  3
# current learning rate: 0.005
# Epoch:  4
# Val loss: tensor(0.6855)
# current learning rate: 0.005
# Epoch:  5
# current learning rate: 0.005
# Epoch:  6
# Val loss: tensor(0.5248)
# current learning rate: 0.005
# Epoch:  7
# current learning rate: 0.005
# Epoch:  8
# Val loss: tensor(0.5202)
# current learning rate: 0.005
# Epoch:  9
# current learning rate: 0.005
# Epoch:  10
# Val loss: tensor(0.4609)
# current learning rate: 0.005
# Epoch:  11
# current learning rate: 0.005
# Epoch:  12
# Val loss: tensor(0.3415)
# current learning rate: 0.005
# Epoch:  13
# current learning rate: 0.005
# Epoch:  14
# Val loss: tensor(0.2091)
# current learning rate: 0.005
# Epoch:  15
# current learning rate: 0.005
# Epoch:  16
# Val loss: tensor(0.2171)
# current learning rate: 0.005
# Epoch:  17
# current learning rate: 0.005
# Epoch:  18
# Val loss: tensor(0.0935)
# current learning rate: 0.005
# Epoch:  19
# current learning rate: 0.005
# Epoch:  20
# Val loss: tensor(0.0622)
# current learning rate: 0.005
# Epoch:  21
# current learning rate: 0.005
# Epoch:  22
# Val loss: tensor(0.3905)
# current learning rate: 0.005
# Epoch:  23
# current learning rate: 0.005
# Epoch:  24
# Val loss: tensor(0.0468)
# current learning rate: 0.005
# Epoch:  25
# current learning rate: 0.005
# Epoch:  26
# Val loss: tensor(0.2947)
# current learning rate: 0.005
# Epoch:  27
# current learning rate: 0.005
# Epoch:  28
# Val loss: tensor(0.1926)
# current learning rate: 0.005
# Epoch:  29
# current learning rate: 0.005
# Epoch:  30
# Val loss: tensor(0.1347)
# current learning rate: 0.005
# Epoch:  31
# current learning rate: 0.005
# Epoch:  32
# Val loss: tensor(0.4394)
# current learning rate: 0.005
# Epoch:  33
# current learning rate: 0.005
# Epoch:  34
# Val loss: tensor(0.2285)
# current learning rate: 0.005
# Epoch:  35
# current learning rate: 0.005
# Epoch:  36
# Epoch    18: reducing learning rate of group 0 to 2.5000e-03.
# Val loss: tensor(0.1270)
# current learning rate: 0.0025
# Epoch:  37
# current learning rate: 0.0025
# Epoch:  38
# Val loss: tensor(0.0845)
# current learning rate: 0.0025
# Epoch:  39
# current learning rate: 0.0025
# Epoch:  40
# Val loss: tensor(0.0475)
# current learning rate: 0.0025
# Epoch:  41
# current learning rate: 0.0025
# Epoch:  42
# Val loss: tensor(0.0423)
# current learning rate: 0.0025
# Epoch:  43
# current learning rate: 0.0025
# Epoch:  44
# Val loss: tensor(0.0407)
# current learning rate: 0.0025
# Epoch:  45
# current learning rate: 0.0025
# Epoch:  46
# Val loss: tensor(0.3055)
# current learning rate: 0.0025
# Epoch:  47
# current learning rate: 0.0025
# Epoch:  48
# Val loss: tensor(0.0903)
# current learning rate: 0.0025
# Epoch:  49
# current learning rate: 0.0025
# Epoch:  50
# Val loss: tensor(0.0951)
# current learning rate: 0.0025
# Epoch:  51
# current learning rate: 0.0025
# Epoch:  52
# Val loss: tensor(0.0405)
# current learning rate: 0.0025
# Epoch:  53
# current learning rate: 0.0025
# Epoch:  54
# Val loss: tensor(0.0303)
# current learning rate: 0.0025
# Epoch:  55
# current learning rate: 0.0025
# Epoch:  56
# Val loss: tensor(0.0287)
# current learning rate: 0.0025
# Epoch:  57
# current learning rate: 0.0025
# Epoch:  58
# Val loss: tensor(0.0833)
# current learning rate: 0.0025
# Epoch:  59
# current learning rate: 0.0025
# Epoch:  60
# Val loss: tensor(0.0498)
# current learning rate: 0.0025
# Epoch:  61
# current learning rate: 0.0025
# Epoch:  62
# Val loss: tensor(0.0363)
# current learning rate: 0.0025
# Epoch:  63
# current learning rate: 0.0025
# Epoch:  64
# Val loss: tensor(0.0343)
# current learning rate: 0.0025
# Epoch:  65
# current learning rate: 0.0025
# Epoch:  66
# Val loss: tensor(0.3064)
# current learning rate: 0.0025
# Epoch:  67
# current learning rate: 0.0025
# Epoch:  68
# Epoch    34: reducing learning rate of group 0 to 1.2500e-03.
# Val loss: tensor(0.0715)
# current learning rate: 0.00125
# Epoch:  69
# current learning rate: 0.00125
# Epoch:  70
# Val loss: tensor(0.0523)
# current learning rate: 0.00125
# Epoch:  71
# current learning rate: 0.00125
# Epoch:  72
# Val loss: tensor(0.0392)
# current learning rate: 0.00125
# Epoch:  73
# current learning rate: 0.00125
# Epoch:  74
# Val loss: tensor(0.0681)
# current learning rate: 0.00125
# Epoch:  75
# current learning rate: 0.00125
# Epoch:  76
# Val loss: tensor(0.0285)
# current learning rate: 0.00125
# Epoch:  77
# current learning rate: 0.00125
# Epoch:  78
# Val loss: tensor(0.0253)
# current learning rate: 0.00125
# Epoch:  79
# current learning rate: 0.00125
# Epoch:  80
# Val loss: tensor(0.0297)
# current learning rate: 0.00125
# Epoch:  81
# current learning rate: 0.00125
# Epoch:  82
# Val loss: tensor(0.0298)
# current learning rate: 0.00125
# Epoch:  83
# current learning rate: 0.00125
# Epoch:  84
# Val loss: tensor(0.0294)
# current learning rate: 0.00125
# Epoch:  85
# current learning rate: 0.00125
# Epoch:  86
# Val loss: tensor(0.0277)
# current learning rate: 0.00125
# Epoch:  87
# current learning rate: 0.00125
# Epoch:  88
# Val loss: tensor(0.0634)
# current learning rate: 0.00125
# Epoch:  89
# current learning rate: 0.00125
# Epoch:  90
# Val loss: tensor(0.0241)
# current learning rate: 0.00125
# Epoch:  91
# current learning rate: 0.00125
# Epoch:  92
# Val loss: tensor(0.0266)
# current learning rate: 0.00125
# Epoch:  93
# current learning rate: 0.00125
# Epoch:  94
# Val loss: tensor(0.0262)
# current learning rate: 0.00125
# Epoch:  95
# current learning rate: 0.00125
# Epoch:  96
# Val loss: tensor(0.0303)
# current learning rate: 0.00125
# Epoch:  97
# current learning rate: 0.00125
# Epoch:  98
# Val loss: tensor(0.1339)
# current learning rate: 0.00125
# Epoch:  99
# current learning rate: 0.00125
# Epoch:  100
# Val loss: tensor(0.0253)
# current learning rate: 0.00125
# Epoch:  101
# current learning rate: 0.00125
# Epoch:  102
# Val loss: tensor(0.0227)
# current learning rate: 0.00125
# Epoch:  103
# current learning rate: 0.00125
# Epoch:  104
# Val loss: tensor(0.1216)
# current learning rate: 0.00125
# Epoch:  105
# current learning rate: 0.00125
# Epoch:  106
# Val loss: tensor(0.0376)
# current learning rate: 0.00125
# Epoch:  107
# current learning rate: 0.00125
# Epoch:  108
# Val loss: tensor(0.0262)
# current learning rate: 0.00125
# Epoch:  109
# current learning rate: 0.00125
# Epoch:  110
# Val loss: tensor(0.0235)
# current learning rate: 0.00125
# Epoch:  111
# current learning rate: 0.00125
# Epoch:  112
# Val loss: tensor(0.0318)
# current learning rate: 0.00125
# Epoch:  113
# current learning rate: 0.00125
# Epoch:  114
# Epoch    57: reducing learning rate of group 0 to 6.2500e-04.
# Val loss: tensor(0.0247)
# current learning rate: 0.000625
# Epoch:  115
# current learning rate: 0.000625
# Epoch:  116
# Val loss: tensor(0.0233)
# current learning rate: 0.000625
# Epoch:  117
# current learning rate: 0.000625
# Epoch:  118
# Val loss: tensor(0.0521)
# current learning rate: 0.000625
# Epoch:  119
# current learning rate: 0.000625
# Epoch:  120
# Val loss: tensor(0.0214)
# current learning rate: 0.000625
# Epoch:  121
# current learning rate: 0.000625
# Epoch:  122
# Val loss: tensor(0.0231)
# current learning rate: 0.000625
# Epoch:  123
# current learning rate: 0.000625
# Epoch:  124
# Val loss: tensor(0.0221)
# current learning rate: 0.000625
# Epoch:  125
# current learning rate: 0.000625
# Epoch:  126
# Val loss: tensor(0.0487)
# current learning rate: 0.000625
# Epoch:  127
# current learning rate: 0.000625
# Epoch:  128
# Val loss: tensor(0.0217)
# current learning rate: 0.000625
# Epoch:  129
# current learning rate: 0.000625
# Epoch:  130
# Val loss: tensor(0.0503)
# current learning rate: 0.000625
# Epoch:  131
# current learning rate: 0.000625
# Epoch:  132
# Val loss: tensor(0.0211)
# current learning rate: 0.000625
# Epoch:  133
# current learning rate: 0.000625
# Epoch:  134
# Val loss: tensor(0.0210)
# current learning rate: 0.000625
# Epoch:  135
# current learning rate: 0.000625
# Epoch:  136
# Val loss: tensor(0.0228)
# current learning rate: 0.000625
# Epoch:  137
# current learning rate: 0.000625
# Epoch:  138
# Val loss: tensor(0.0259)
# current learning rate: 0.000625
# Epoch:  139
# current learning rate: 0.000625
# Epoch:  140
# Val loss: tensor(0.0234)
# current learning rate: 0.000625
# Epoch:  141
# current learning rate: 0.000625
# Epoch:  142
# Val loss: tensor(0.0214)
# current learning rate: 0.000625
# Epoch:  143
# current learning rate: 0.000625
# Epoch:  144
# Val loss: tensor(0.1472)
# current learning rate: 0.000625
# Epoch:  145
# current learning rate: 0.000625
# Epoch:  146
# Epoch    73: reducing learning rate of group 0 to 3.1250e-04.
# Val loss: tensor(0.0260)
# current learning rate: 0.0003125
# Epoch:  147
# current learning rate: 0.0003125
# Epoch:  148
# Val loss: tensor(0.0228)
# current learning rate: 0.0003125
# Epoch:  149
# current learning rate: 0.0003125
# Epoch:  150
# Val loss: tensor(0.0213)
# current learning rate: 0.0003125
# Epoch:  151
# current learning rate: 0.0003125
# Epoch:  152
# Val loss: tensor(0.0211)
# current learning rate: 0.0003125
# Epoch:  153
# current learning rate: 0.0003125
# Epoch:  154
# Val loss: tensor(0.0229)
# current learning rate: 0.0003125
# Epoch:  155
# current learning rate: 0.0003125
# Epoch:  156
# Val loss: tensor(0.0210)
# current learning rate: 0.0003125
# Epoch:  157
# current learning rate: 0.0003125
# Epoch:  158
# Val loss: tensor(0.0208)
# current learning rate: 0.0003125
# Epoch:  159
# current learning rate: 0.0003125
# Epoch:  160
# Val loss: tensor(0.0219)
# current learning rate: 0.0003125
# Epoch:  161
# current learning rate: 0.0003125
# Epoch:  162
# Val loss: tensor(0.0207)
# current learning rate: 0.0003125
# Epoch:  163
# current learning rate: 0.0003125
# Epoch:  164
# Val loss: tensor(0.0200)
# current learning rate: 0.0003125
# Epoch:  165
# current learning rate: 0.0003125
# Epoch:  166
# Val loss: tensor(0.0228)
# current learning rate: 0.0003125
# Epoch:  167
# current learning rate: 0.0003125
# Epoch:  168
# Val loss: tensor(0.0216)
# current learning rate: 0.0003125
# Epoch:  169
# current learning rate: 0.0003125
# Epoch:  170
# Val loss: tensor(0.0264)
# current learning rate: 0.0003125
# Epoch:  171
# current learning rate: 0.0003125
# Epoch:  172
# Val loss: tensor(0.0202)
# current learning rate: 0.0003125
# Epoch:  173
# current learning rate: 0.0003125
# Epoch:  174
# Val loss: tensor(0.0209)
# current learning rate: 0.0003125
# Epoch:  175
# current learning rate: 0.0003125
# Done Training
# Testing the final Model
# Testing the best Model
# Finished Training: SimpleRNNLPB1_Parameterized_LSTM_hs20_pre_high_pass

# %% [markdown]
# # Two Parameter Training

# %%
# !python prep_wav.py "DS1_Parameterized" -p "./Configs/Parameterization-Config-2.json"
# Out:
# Parameterized Data
# /home/micahtseng/Personal/mlamsk/python3Env/pytorchSandbox/Automated-GuitarAmpModelling/prep_wav.py:169: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   in_rate, in_data = wavfile.read(ds["TrainingClean"])
# /home/micahtseng/Personal/mlamsk/python3Env/pytorchSandbox/Automated-GuitarAmpModelling/prep_wav.py:170: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   out_rate, out_data = wavfile.read(ds["TrainingTarget"])
# /home/micahtseng/Personal/mlamsk/python3Env/pytorchSandbox/Automated-GuitarAmpModelling/prep_wav.py:171: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   test_in_rate, test_in_data = wavfile.read(ds["TestClean"])
# /home/micahtseng/Personal/mlamsk/python3Env/pytorchSandbox/Automated-GuitarAmpModelling/prep_wav.py:172: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   test_out_rate, test_out_data = wavfile.read(ds["TestTarget"])

# %%
# !python dist_model_recnet.py -l RNN3-DS1_Parameterized -eps 5 --seed 39 -lm False -is 3
